# %%
import pandas
import numpy

# %%
df = pandas.read_csv('tmdb_5000_movies.csv')

# %%
df_movies = df[['id','budget', 'title', 'release_date', 'revenue', 'vote_average', 'vote_count']]

# %%
df_movies
# Out:
#           id     budget                                              title  \
# 0          5    4000000                                         Four Rooms
# 1         11   11000000                                          Star Wars
# 2         12   94000000                                       Finding Nemo
# 3         13   55000000                                       Forrest Gump
# 4         14   15000000                                    American Beauty
# 5         16   12800000                                 Dancer in the Dark
# 6         18   90000000                                  The Fifth Element
# 7         19   92620000                                         Metropolis
# 8         20          0                                 My Life Without Me
# 9         22  140000000  Pirates of the Caribbean: The Curse of the Bla...
# 10        24   30000000                                  Kill Bill: Vol. 1
# ...

# %%
credits = pandas.read_csv('tmdb_5000_credits.csv')

# %%
df_credits = credits[['movie_id','cast']]

# %%
df_credits
# Out:
#                                           movie_id  \
# 0                                                4
# 1                                                5
# 2                                                9
# 3                                               11
# 4                                               12
# 5                                               13
# 6                                               14
# 7                                               16
# 8                                               18
# 9                                               19
# 10                                              20
# 11                                              22
# 12                                              24
# 13                                              25
# 14                                              28
# 15                                              33
# 16                                              35
# ...

# %%
df = df_movies.join(df_credits, lsuffix='id', rsuffix='movie_id')

# %%
df
# Out:
#           id     budget                                              title  \
# 0          5    4000000                                         Four Rooms
# 1         11   11000000                                          Star Wars
# 2         12   94000000                                       Finding Nemo
# 3         13   55000000                                       Forrest Gump
# 4         14   15000000                                    American Beauty
# 5         16   12800000                                 Dancer in the Dark
# 6         18   90000000                                  The Fifth Element
# 7         19   92620000                                         Metropolis
# 8         20          0                                 My Life Without Me
# 9         22  140000000  Pirates of the Caribbean: The Curse of the Bla...
# 10        24   30000000                                  Kill Bill: Vol. 1
# ...
